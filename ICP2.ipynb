# %% [markdown]
# <a href="https://colab.research.google.com/github/ans90990/ICP2/blob/main/ICP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1

ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

for i in range(len(ages) - 1):

        #store the current minimum value and its index
        currentMin = ages[i]
        currentMinIndex = i

        #select the smallest element
        for j in range(i + 1, len(ages)):

            #checking if the current min is greater than the value in the index
            if currentMin > ages[j]:
                currentMin = ages[j]
                currentMinIndex = j

        #swap list[i] with the current min index if neccesary
        if currentMinIndex != i:
            ages[currentMinIndex] = ages[i]
            ages[i] = currentMin
print(ages)
print(max(ages))
print(min(ages))
#find and print the median
if len(ages) % 2 == 0:
    print("Meidan = ", (ages[int(len(ages)/2)]))
else:
    print("Median =", ((ages[int(len(ages/2))]) + (ages[int(len(ages/2 + 1))]) / 2))
#find and print the average
sum = 0
for i in range(len(ages)- 1):
    sum = sum + ages[i]
print(sum/len(ages))
#find and print the range of ages
range = max(ages) - min(ages)
print(range)


#Q2
dogs = {}
dogs["name"] = "Poppy"
dogs["color"] = "brown"
dogs["breed"] = "chocolate Lab"
dogs["legs"] = "3"
dogs["age"] = "5"

student = {}
student["first_name"] = "Amber"
student["last_name"] = "smith"
student["gender"] = "f"
student["age"] = "24"
student["marital_status"] = "single"
student["skills"] = ["A", "Few", "Things"]
student["country"] = "USA"
student["city"] = "Warrensburg"
student["address"] = "1990 carpenter ave"
print(len(student))
print(student["skills"])
print(type(student["skills"]))
lst = "More", "Things"
student["skills"].extend(lst)
print(student["skills"])
print(student.keys())
print(student.values())

#Q3
it_companies = {'Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon'}
A = {19, 22, 24, 20, 25, 26}
B = {19, 22, 20, 25, 26, 24, 28, 27}
age = [22, 19, 24, 25, 26, 24, 25, 24]
print(len(it_companies))
it_companies.add('Twitter')
moreCompanies = {'More','companies'}
it_companies = set.union(it_companies, moreCompanies)
print(it_companies)
it_companies.remove('More')
print(it_companies)

print("The difference between remove and discard is that remove will give an error if the item doesn't exist while discard will not")
AandB = set.union(A, B)
print(AandB)
print("the intersection of A and B is: 19, 22, 20, 24, 25, 26")
print("A is a subset of B")
print("A and B are not disjoint sets")
print(AandB)
BandA = set.union(B, A)
print(BandA)
print("the symetric difference is 28 and 27")
set.clear(A)
set.clear(B)
set(ages)
print(len(ages))
print("length of set ages and list ages is the same")


#Q4
class Employee:
    #variable to count number of employees
    numEmployees = 0
    #constructor to initialize name family salary and department
    def __init__(self, name, family, salary, department):
        self.name = name
        self.family = family
        self.salary = salary
        self.department = department
        Employee.numEmployees = Employee.numEmployees + 1

    #create a function to average salary
    def averageSalary(employees):
        totalSalary = sum(employee.salary for employee in employees)
        averageSalary = totalSalary / len(employees)
        return averageSalary

#create class for fulltime employee that inherits from employee
class FullTimeEmployee(Employee):
    def __init__(self, name, family, salary, department):
        super().__init__(name, family, salary, department)
#create instances of employee
employee1 = Employee("JJ", "Austin", 45000, "IT")
employee2 = Employee("AA", "Apples", 50000, "IT")

#create instances of fulltime employee
employee3 = FullTimeEmployee("AJ", "branson", 80000, "IT Management")
employee4 = FullTimeEmployee("Amber", "Smith", 90000,"owner")

#call all the member functions
employees1 = [employee1, employee2]
averageSalary = Employee.averageSalary(employees1)

employees2 = [employee3, employee4]
averageFullSalary = FullTimeEmployee.averageSalary(employees2)
